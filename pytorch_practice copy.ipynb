# %%
import torch

# %%
x = torch.tensor([5.5, 3])
print(x)
# Out:
# tensor([5.5000, 3.0000])

# %%
x = torch.tensor( [ [1, 2] ,
                    [3, 4],
                    [5, 6] 
                ])
print(x.shape)
# Out:
# torch.Size([3, 2])
